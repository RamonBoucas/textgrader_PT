# %%
# %reload_kedro

import pandas as pd
import numpy as np
from textgrader.pipelines.data_processing.functions import *
from textgrader.pipelines.data_processing.config import *
# Out:
# [10/29/23 12:21:41] INFO     Resolved project path as:                                              ]8;id=668849;file://C:\Users\ramon.boucas\Miniconda3\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=480609;file://C:\Users\ramon.boucas\Miniconda3\lib\site-packages\kedro\ipython\__init__.py#142\142]8;;\
#                              C:\Users\ramon.boucas\Desktop\pesquisa_kedro\textgrader.
#                              To set a different path, run '%reload_kedro <project_root>'
# [10/29/23 12:21:42] INFO     Kedro project textgrader                                               ]8;id=516465;file://C:\Users\ramon.boucas\Miniconda3\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=443481;file://C:\Users\ramon.boucas\Miniconda3\lib\site-packages\kedro\ipython\__init__.py#108\108]8;;\
# ...

# %%
df = catalog.load('all_texts_with_targets')
df
# Out:
# [10/29/23 12:21:44] INFO     Loading data from 'all_texts_with_targets' (ParquetDataSet)...     ]8;id=453874;file://C:\Users\ramon.boucas\Miniconda3\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=420732;file://C:\Users\ramon.boucas\Miniconda3\lib\site-packages\kedro\io\data_catalog.py#503\503]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#      tema                                              texto  \
# 0       1  Recentemente veio à tona na mídia mundial algu...
# 1       1  O futebol, considerado o esporte mais popular ...
# 2       1  ''Nada mais importa. Nem cor, nem dinheiro, ne...
# 3       1  Segundo a Constituição federal brasileira de 1...
# 4       1  O racismo no futebol é um assunto comum, porém...
# ..    ...                                                ...
# 109   168  Após a destruição do polêmico Muro de Berlim, ...
# ...
