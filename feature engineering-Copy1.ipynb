# %%
FROM

# %%
segundo_df[TARGETS_2].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5437 entries, 3 to 13594
# Data columns (total 5 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Adequação ao Tema_nota                         5437 non-null   float64
#  1   Adequação e Leitura Crítica da Coletânea_nota  5437 non-null   float64
#  2   Adequação ao Gênero Textual_nota               5437 non-null   float64
#  3   Adequação à modalidade padrão da língua_nota   5437 non-null   float64
#  4   Coesão e Coerência_nota                        5437 non-null   float64
# dtypes: float64(5)
# memory usage: 254.9 KB

# %%
segundo_df
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#        index  tema                                    texto_comentado  \
# 3         83   106  A reforma política de um país está ligada a à ...
# 4         42   126  O povo brasileiro da região nordeste vem lutan...
# 5        129   121  Aquecimento global é o maior agravante dos últ...
# 9         32    93  Parques, ruas, transporte coletivo, estádios, ...
# 15       136   133  Há um bom tempo no Brasil, os acidentes de trâ...
# ...      ...   ...                                                ...
# 13588     61    97  Uma grande parte da população brasileira, prin...
# 13590    104   117  O onze de setembro com certeza ficou marcado n...
# 13591     79    97  A homossexualidade está sendo cada vez mais di...
# 13593     27    89  O ministro da saúde Marcelo Castro, causou pol...
# ...

# %%
df = catalog.load('primeira_pred_geral')
df
# Out:
#                     INFO     Loading data from 'primeira_pred_geral' (ParquetDataSet)...        ]8;id=412086;file://C:\Users\ramon.boucas\Miniconda3\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=625893;file://C:\Users\ramon.boucas\Miniconda3\lib\site-packages\kedro\io\data_catalog.py#503\503]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       index  tema  conjunto  Domínio da modalidade escrita formal_nota_pred  \
# 0        17    78         1                                             141
# 2         1    77         1                                             151
# 3        58    83         1                                             146
# 4        48     8         1                                             137
# 5        43    51         1                                             157
# ...

# %%
df = catalog.load('primeira_pred_especifica')
df
# Out:
# [10/29/23 17:04:02] INFO     Loading data from 'primeira_pred_especifica' (ParquetDataSet)...   ]8;id=464992;file://C:\Users\ramon.boucas\Miniconda3\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=476768;file://C:\Users\ramon.boucas\Miniconda3\lib\site-packages\kedro\io\data_catalog.py#503\503]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       index  tema  conjunto  Domínio da modalidade escrita formal_nota_pred  \
# 0         0     1         1                                             134
# 1        36     1         1                                             158
# 2        35     1         1                                             157
# 3       104     1         1                                             151
# 4        65     1         1                                             133
# ...

# %%
df = catalog.load('primeiro_teste')
df = df[config.ID_VARS + TARGETS_1]
# Out:
# [10/29/23 17:05:44] INFO     Loading data from 'primeiro_teste' (ParquetDataSet)...             ]8;id=874526;file://C:\Users\ramon.boucas\Miniconda3\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=168269;file://C:\Users\ramon.boucas\Miniconda3\lib\site-packages\kedro\io\data_catalog.py#503\503]8;;\
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:2                                                                                    │
# │                                                                                                  │
# │   1 df = catalog.load('primeiro_teste')                                                          │
# │ ❱ 2 df = df[config.ID_VARS + TARGETS_1]                                                          │
# │   3                                                                                              │
# ...

# %%
df = catalog.load('final_scores_experiment')
df
# Out:
#                     INFO     Loading data from 'final_scores_experiment' (ParquetDataSet)...    ]8;id=667461;file://C:\Users\ramon.boucas\Miniconda3\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=73472;file://C:\Users\ramon.boucas\Miniconda3\lib\site-packages\kedro\io\data_catalog.py#503\503]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                             conceito  score_geral  \
# 0  Compreender a proposta e aplicar conceitos das...     0.001174
# 1  Conhecimento dos mecanismos linguísticos neces...     0.000493
# 2               Domínio da modalidade escrita formal     0.000629
# 3  Proposta de intervenção com respeito aos direi...    -0.001060
# 4  Selecionar, relacionar, organizar e interpreta...    -0.005106
#
#    score_especifica
# 0          0.001927
# 1         -0.000259
# 2          0.000335
# 3          0.000826
# ...
